# %%
# !pip install websocket_client
# Out:
# Collecting websocket_client
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 5.0MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from websocket_client) (1.15.0)
# Installing collected packages: websocket-client
# Successfully installed websocket-client-0.57.0

# %%
import logging
import threading
import time

# %%
from websocket import create_connection

# %%
uri = "ws://35.214.36.98:5010/ws/"

# %%
def hello_world(threadid):
  ws = create_connection(uri)
  print("Sending 'Hello, World'...")
  message = "Hello, World from " + str(threadid)
  ws.send(message)
  print("Sent")
  print("Receiving...")
  result =  ws.recv()
  print("Received '%s'" % result)
  ws.close()

# %%
hello_world(1)
# Out:
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/8'

# %%
def thread_function(name):
    logging.info("Thread %s: starting", name)
    time.sleep(2)
    logging.info("Thread %s: finishing", name)

# %%
for q in range(0, 100):
  format = "%(asctime)s: %(message)s"
  logging.basicConfig(format=format, level=logging.INFO,
                      datefmt="%H:%M:%S")

  logging.info("Main    : before creating thread")
  x = threading.Thread(target=hello_world(1), args=(1,))
  y = threading.Thread(target=hello_world(2), args=(2,))
  z = threading.Thread(target=hello_world(3), args=(3,))
  logging.info("Main    : before running thread")
  x.start()
  y.start()
  z.start()
  logging.info("Main    : wait for the thread to finish")
  # x.join()
  logging.info("Main    : all done")
# Out:
# 19:53:04: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/9'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/10'
# 19:53:05: Main    : before running thread
# 19:53:05: Main    : wait for the thread to finish
# 19:53:05: Main    : all done
# 19:53:05: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/11'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/12'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/13'
# 19:53:07: Main    : before running thread
# 19:53:07: Main    : wait for the thread to finish
# 19:53:07: Main    : all done
# 19:53:07: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/14'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/15'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/16'
# 19:53:08: Main    : before running thread
# 19:53:08: Main    : wait for the thread to finish
# 19:53:08: Main    : all done
# 19:53:08: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/17'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/18'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/19'
# 19:53:09: Main    : before running thread
# 19:53:09: Main    : wait for the thread to finish
# 19:53:09: Main    : all done
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/20'
# 19:53:09: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/21'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/22'
# 19:53:10: Main    : before running thread
# 19:53:10: Main    : wait for the thread to finish
# 19:53:10: Main    : all done
# 19:53:10: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/23'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/24'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/25'
# 19:53:11: Main    : before running thread
# 19:53:11: Main    : wait for the thread to finish
# 19:53:11: Main    : all done
# 19:53:11: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/26'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/27'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/28'
# 19:53:12: Main    : before running thread
# 19:53:12: Main    : wait for the thread to finish
# 19:53:12: Main    : all done
# 19:53:12: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/29'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/30'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/31'
# 19:53:13: Main    : before running thread
# 19:53:14: Main    : wait for the thread to finish
# 19:53:14: Main    : all done
# 19:53:14: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/32'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/33'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/34'
# 19:53:15: Main    : before running thread
# 19:53:15: Main    : wait for the thread to finish
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/35'
# 19:53:15: Main    : all done
# 19:53:15: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/36'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/37'
# 19:53:16: Main    : before running thread
# 19:53:16: Main    : wait for the thread to finish
# 19:53:16: Main    : all done
# 19:53:16: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/38'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/39'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/40'
# 19:53:17: Main    : before running thread
# 19:53:17: Main    : wait for the thread to finish
# 19:53:17: Main    : all done
# 19:53:17: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/41'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/42'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/43'
# 19:53:18: Main    : before running thread
# 19:53:18: Main    : wait for the thread to finish
# 19:53:18: Main    : all done
# 19:53:18: Main    : before creating thread
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 3/answer/44'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 1/answer/45'
# Sending 'Hello, World'...
# Sent
# Receiving...
# Received 'Hello, World from 2/answer/46'
